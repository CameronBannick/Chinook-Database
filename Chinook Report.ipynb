# %% [markdown]
# # Import libraries

# %%
#standard imports
import numpy as np
import pandas as pd 
#data visual imports
import matplotlib.pyplot as plt
import seaborn as sns
#sql alchemy imports 
from sqlalchemy import create_engine 
from sqlalchemy_utils import create_database, database_exists

# %% [markdown]
# # Connect to mySQL database; Chinook

# %%
#save path as variable 
connection = "mysql+pymysql://root:root@localhost/chinook"
#create engine with connection
engine = create_engine(connection)
#call engine
engine
# Out:
# Engine(mysql+pymysql://root:***@localhost/chinook)

# %%
#call if else statement to see if database exists
if database_exists(connection)==False:
    create_database(connection) 
else: print("Database exists")
# Out:
# Database exists

# %% [markdown]
# # Inspect database

# %%
#save information_schema query as variable 
q = """SELECT table_name
       FROM information_schema.tables
       WHERE table_schema = 'chinook';"""
#call pd read sql to run query
pd.read_sql(q, engine)
# Out:
#        TABLE_NAME
# 0           album
# 1          artist
# 2        customer
# 3        employee
# 4           genre
# 5         invoice
# 6     invoiceline
# 7       mediatype
# 8        playlist
# 9   playlisttrack
# 10          track

# %%
#save query to inspect album table
q= """SELECT *
      FROM album;"""
#call pd read sql to run query
pd.read_sql(q, engine).head()
# Out:
#    AlbumId                                  Title  ArtistId
# 0        1  For Those About To Rock We Salute You         1
# 1        2                      Balls to the Wall         2
# 2        3                      Restless and Wild         2
# 3        4                      Let There Be Rock         1
# 4        5                               Big Ones         3

# %%
#save query to inspect artist table
q="""SELECT * 
     FROM artist;"""
#call pd read sql to run query 
pd.read_sql(q, engine).head()
# Out:
#    ArtistId               Name
# 0         1              AC/DC
# 1         2             Accept
# 2         3          Aerosmith
# 3         4  Alanis Morissette
# 4         5    Alice In Chains

# %%
#save query to inspect customer table 
q = """SELECT *
       FROM customer;"""
#call pandas to read query 
pd.read_sql(q, engine).head()
# Out:
#    CustomerId  FirstName     LastName  \
# 0           1       Luís    Gonçalves
# 1           2     Leonie       Köhler
# 2           3   François     Tremblay
# 3           4      Bjørn       Hansen
# 4           5  František  Wichterlová
#
#                                             Company  \
# 0  Embraer - Empresa Brasileira de Aeronáutica S.A.
# 1                                              None
# 2                                              None
# 3                                              None
# 4                                  JetBrains s.r.o.
#
#                            Address                 City State         Country  \
# 0  Av. Brigadeiro Faria Lima, 2170  São José dos Campos    SP          Brazil
# 1          Theodor-Heuss-Straße 34            Stuttgart  None         Germany
# 2                1498 rue Bélanger             Montréal    QC          Canada
# 3                 Ullevålsveien 14                 Oslo  None          Norway
# ...

# %%
#save query to inspect employee table 
q = """SELECT *
       FROM employee;"""
#call pandas to read query 
pd.read_sql(q, engine).head()
# Out:
#    EmployeeId LastName FirstName                Title  ReportsTo  BirthDate  \
# 0           1    Adams    Andrew      General Manager        NaN 1962-02-18
# 1           2  Edwards     Nancy        Sales Manager        1.0 1958-12-08
# 2           3  Peacock      Jane  Sales Support Agent        2.0 1973-08-29
# 3           4     Park  Margaret  Sales Support Agent        2.0 1947-09-19
# 4           5  Johnson     Steve  Sales Support Agent        2.0 1965-03-03
#
#     HireDate              Address      City State Country PostalCode  \
# 0 2002-08-14  11120 Jasper Ave NW  Edmonton    AB  Canada    T5K 2N1
# 1 2002-05-01         825 8 Ave SW   Calgary    AB  Canada    T2P 2T3
# 2 2002-04-01        1111 6 Ave SW   Calgary    AB  Canada    T2P 5M5
# 3 2003-05-03     683 10 Street SW   Calgary    AB  Canada    T2P 5G3
# 4 2003-10-17         7727B 41 Ave   Calgary    AB  Canada    T3B 1Y7
#
#                Phone                Fax                     Email
# ...

# %%
#save query to inspect genre table 
q = """SELECT *
       FROM genre;"""
#call pandas to read query 
pd.read_sql(q, engine).head()
# Out:
#    GenreId                Name
# 0        1                Rock
# 1        2                Jazz
# 2        3               Metal
# 3        4  Alternative & Punk
# 4        5       Rock And Roll

# %%
#save query to inspect invoice table 
q = """SELECT *
       FROM invoice;"""
#call pandas to read query 
pd.read_sql(q, engine).head()
# Out:
#    InvoiceId  CustomerId InvoiceDate           BillingAddress BillingCity  \
# 0          1           2  2009-01-01  Theodor-Heuss-Straße 34   Stuttgart
# 1          2           4  2009-01-02         Ullevålsveien 14        Oslo
# 2          3           8  2009-01-03          Grétrystraat 63    Brussels
# 3          4          14  2009-01-06           8210 111 ST NW    Edmonton
# 4          5          23  2009-01-11          69 Salem Street      Boston
#
#   BillingState BillingCountry BillingPostalCode  Total
# 0         None        Germany             70174   1.98
# 1         None         Norway              0171   3.96
# 2         None        Belgium              1000   5.94
# 3           AB         Canada           T6G 2C7   8.91
# 4           MA            USA              2113  13.86

# %%
#save query to inspect invoiceline table 
q = """SELECT *
       FROM invoiceline;"""
#call pandas to read query 
pd.read_sql(q, engine).head()
# Out:
#    InvoiceLineId  InvoiceId  TrackId  UnitPrice  Quantity
# 0              1          1        2       0.99         1
# 1              2          1        4       0.99         1
# 2              3          2        6       0.99         1
# 3              4          2        8       0.99         1
# 4              5          2       10       0.99         1

# %%
#save query to inspect mediatype table 
q = """SELECT *
       FROM mediatype;"""
#call pandas to read query 
pd.read_sql(q, engine).head()
# Out:
#    MediaTypeId                         Name
# 0            1              MPEG audio file
# 1            2     Protected AAC audio file
# 2            3  Protected MPEG-4 video file
# 3            4     Purchased AAC audio file
# 4            5               AAC audio file

# %%
#save query to inspect playlist table 
q = """SELECT *
       FROM playlist;"""
#call pandas to read query 
pd.read_sql(q, engine).head()
# Out:
#    PlaylistId        Name
# 0           1       Music
# 1           2      Movies
# 2           3    TV Shows
# 3           4  Audiobooks
# 4           5  90’s Music

# %%
#save query to inspect playlisttrack table 
q = """SELECT *
       FROM playlisttrack;"""
#call pandas to read query 
pd.read_sql(q, engine).head()
# Out:
#    PlaylistId  TrackId
# 0           1        1
# 1           8        1
# 2          17        1
# 3           1        2
# 4           8        2

# %%
#save query to inspect track table 
q = """SELECT *
       FROM track;"""
#call pandas to read query 
pd.read_sql(q, engine).head()
# Out:
#    TrackId                                     Name  AlbumId  MediaTypeId  \
# 0        1  For Those About To Rock (We Salute You)        1            1
# 1        2                        Balls to the Wall        2            2
# 2        3                          Fast As a Shark        3            2
# 3        4                        Restless and Wild        3            2
# 4        5                     Princess of the Dawn        3            2
#
#    GenreId                                           Composer  Milliseconds  \
# 0        1          Angus Young, Malcolm Young, Brian Johnson        343719
# 1        1                                               None        342562
# 2        1  F. Baltes, S. Kaufman, U. Dirkscneider & W. Ho...        230619
# 3        1  F. Baltes, R.A. Smith-Diesel, S. Kaufman, U. D...        252051
# 4        1                         Deaffy & R.A. Smith-Diesel        375418
#
#       Bytes  UnitPrice
# 0  11170334       0.99
# ...

# %% [markdown]
# # Exploratory data analysis

# %% [markdown]
# ## What countries use the service?

# %%
#save query as variable
q = """SELECT Country,
              COUNT(*) AS number_of_customers
       FROM customer
       GROUP BY Country
       ORDER BY number_of_customers DESC;"""
#save query as df
df = pd.read_sql(q, engine)
#call pandas to run query
pd.read_sql(q, engine)
# Out:
#            Country  number_of_customers
# 0              USA                   13
# 1           Canada                    8
# 2           Brazil                    5
# 3           France                    5
# 4          Germany                    4
# 5   United Kingdom                    3
# 6   Czech Republic                    2
# 7         Portugal                    2
# 8            India                    2
# 9           Norway                    1
# 10         Austria                    1
# 11         Belgium                    1
# 12         Denmark                    1
# 13         Finland                    1
# 14         Hungary                    1
# 15         Ireland                    1
# 16           Italy                    1
# 17     Netherlands                    1
# 18          Poland                    1
# 19           Spain                    1
# 20          Sweden                    1
# 21       Australia                    1
# ...

# %%
#call countplot
g = sns.barplot(x='Country', y='number_of_customers', data=df)
#set x ticks
plt.xticks(rotation=90)
#set axes labels
plt.xlabel('Country')
plt.ylabel('# of customers')
#set plot title
g.set_title('Customers by country')
#show plot
plt.show()

# %% [markdown]
# The service is currently being used in 24 countries with a number of customers between 1 and 13

# %% [markdown]
# ## What states use our service in the U.S.?

# %%
#save query as variable
q = """SELECT State,
              COUNT(*) AS number_of_customers
       FROM customer 
       WHERE Country = "USA"
       GROUP BY State
       ORDER BY number_of_customers DESC;"""
#save query as df
df = pd.read_sql(q, engine)
#call pandas to run query
pd.read_sql(q, engine)
# Out:
#    State  number_of_customers
# 0     CA                    3
# 1     WA                    1
# 2     NY                    1
# 3     NV                    1
# 4     FL                    1
# 5     MA                    1
# 6     IL                    1
# 7     WI                    1
# 8     TX                    1
# 9     AZ                    1
# 10    UT                    1

# %%
#call countplot
g = sns.barplot(x='State', y='number_of_customers', data=df)
#set x ticks
plt.xticks(rotation=90)
#set axes labels
plt.xlabel('State')
plt.ylabel('# of customers')
#set plot title
g.set_title('Customers by US states')
#show plot
plt.show()

# %% [markdown]
# The service is currently being used in 11 states where there are 7 users in most states except for the number one, California, has 21.

# %% [markdown]
# ## What states in Canada use the service?

# %%
#save query as variable
q = """SELECT State,
              COUNT(*) as number_of_customers
       FROM customer
       WHERE Country = 'Canada'
       GROUP BY State
       ORDER BY number_of_customers DESC;"""
#save query as df
df = pd.read_sql(q, engine)
#call pandas to run query
pd.read_sql(q, engine)
# Out:
#   State  number_of_customers
# 0    ON                    2
# 1    QC                    1
# 2    AB                    1
# 3    BC                    1
# 4    NS                    1
# 5    MB                    1
# 6    NT                    1

# %%
#call countplot
g = sns.barplot(x='State', y='number_of_customers', data=df)
#set x ticks
plt.xticks(rotation=90)
#set axes labels
plt.xlabel('State')
plt.ylabel('# of customers')
#set plot title
g.set_title('Customers by Canadian states')
#show plot
plt.show()

# %% [markdown]
# The service is currently being used in 7 states in Canada with one or two users in each

# %% [markdown]
# ## How much do people typically pay per invoice

# %%
#save query as varaible 
q = """SELECT * 
       FROM invoice;"""
#call pandas to save query as df
df=pd.read_sql(q, engine)
#call head()
df.head()
# Out:
#    InvoiceId  CustomerId InvoiceDate           BillingAddress BillingCity  \
# 0          1           2  2009-01-01  Theodor-Heuss-Straße 34   Stuttgart
# 1          2           4  2009-01-02         Ullevålsveien 14        Oslo
# 2          3           8  2009-01-03          Grétrystraat 63    Brussels
# 3          4          14  2009-01-06           8210 111 ST NW    Edmonton
# 4          5          23  2009-01-11          69 Salem Street      Boston
#
#   BillingState BillingCountry BillingPostalCode  Total
# 0         None        Germany             70174   1.98
# 1         None         Norway              0171   3.96
# 2         None        Belgium              1000   5.94
# 3           AB         Canada           T6G 2C7   8.91
# 4           MA            USA              2113  13.86

# %%
#call describe on total feature
df['Total'].describe()
# Out:
# count    412.000000
# mean       5.651942
# std        4.745320
# min        0.990000
# 25%        1.980000
# 50%        3.960000
# 75%        8.910000
# max       25.860000
# Name: Total, dtype: float64

# %%
#call boxplot
sns.boxplot(x='Total', data=df)
#set axes labels
plt.xlabel('Invoice total ($)')
#show plot
plt.show()

# %%
#call sns hist plot
g = sns.histplot(data=df['Total'])
#call axis title
g.set_title('Histogram for invoice total')
#call axis title
plt.xlabel('Total ($)')
#show plot
plt.show()

# %% [markdown]
# The 50% of invoices run between 2 and 9 dollars with the average invoice total of 5.62. However, with the median being only 3.96 it indicates the average is being skewed by some outliers which can be seen in the box plot as black diamonds. The lowest invoices was 0.99 cents and highest invoice was 25.86 dollars.

# %% [markdown]
# ## How much does each country spend on average?

# %%
#call groupby 
billtot=df.groupby('BillingCountry')['Total'].mean()
#call sns barplot
g = sns.barplot(x=billtot.index, y=billtot.values)
#call title
g.set_title('Avg invoice amount by country')
#rotate x labels
plt.xticks(rotation=90)
#call axis labels 
plt.xlabel('Country')
plt.ylabel('Total ($)')
#show plot
plt.show()

# %% [markdown]
# The largest avg invoice amounts come from Chile, Czech Republic, Hungary, and Ireland despite only have a handful of customers.

# %% [markdown]
# ## What type of audio do customers purchase most?

# %%
#save query as variable 
q = """SELECT p.Name AS media_type,
              COUNT(*) AS downloads
       FROM invoice AS i 
       LEFT JOIN invoiceline AS il 
       ON i.InvoiceId = il.InvoiceId
       LEFT JOIN track AS t
       ON il.TrackId = t.TrackId
       LEFT JOIN playlisttrack AS pl
       ON t.TrackId = pl.TrackId
       LEFT JOIN playlist AS p
       ON pl.PlaylistId = p.PlaylistId
       GROUP BY media_type
       ORDER BY downloads DESC;"""
#call pandas to run query
df = pd.read_sql(q, engine)
#inspect data 
df.head()
# Out:
#         media_type  downloads
# 0            Music       4258
# 1       90’s Music        954
# 2         TV Shows        222
# 3        Classical         41
# 4  Brazilian Music         27

# %%
#call sns catplot
g = sns.catplot(x='media_type', y='downloads', data=df, kind='bar')
#call title
g.fig.suptitle('Media type downloads')
#rotate xlabels
plt.xticks(rotation=90)
#call axis labels
plt.xlabel('Media genre')
#show plot
plt.show()

# %% [markdown]
# The most downloaded media on the site are Music, 90's Music, and TV shows. However, it is overwhelmingly music.

# %% [markdown]
# ## What are the most downloaded genres?

# %%
#save query as Variable 
q = """SELECT g.Name as genre,
              COUNT(*) as downloads
       FROM invoice AS i
       LEFT JOIN invoiceline AS il
       ON i.InvoiceId = il.InvoiceId
       LEFT JOIN track AS t
       ON il.TrackId = t.TrackId
       LEFT JOIN genre AS g
       ON t.GenreId = g.GenreId
       GROUP BY genre
       ORDER BY downloads DESC;"""
#call pandas to run query
df = pd.read_sql(q, engine)
#inspect data 
df.head()
# Out:
#                 genre  downloads
# 0                Rock        835
# 1               Latin        386
# 2               Metal        264
# 3  Alternative & Punk        244
# 4                Jazz         80

# %%
#call sns catplot
g = sns.catplot(x='genre', y='downloads', data=df, kind='bar')
#call title
g.fig.suptitle('Media type downloads')
#rotate xlabels
plt.xticks(rotation=90)
#call axis labels
plt.xlabel('Media genre')
#show plot
plt.show()

# %% [markdown]
# The top 5 downloaded genres are Rock, Latin, Metal, Alternative/Punk, and Jazz.
